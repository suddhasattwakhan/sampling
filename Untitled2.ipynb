# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
import pandas as pd
df = pd.read_csv(r'https://raw.githubusercontent.com/AnjulaMehto/Sampling_Assignment/main/Creditcard_data.csv')

# %%
from sklearn.preprocessing import normalize
Amount = normalize([df['Amount']])[0]
df['Amount'] = Amount
df = df.iloc[:, 1:]
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 1  0.167170  0.125895 -0.008983  0.014724  0.000463      1
# 2 -0.327642 -0.139097 -0.055353 -0.059752  0.065115      0
# 3  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 4 -0.206010  0.502292  0.219422  0.215153  0.012036      0
#
# [5 rows x 30 columns]

# %%
class_freq = df['Class'].value_counts()
print(f"Number of classes: {len(class_freq)}")
print("Class frequencies:")
print(class_freq)
# Out:
# Number of classes: 2
# Class frequencies:
# 0    763
# 1      9
# Name: Class, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Separate features and target
X = df.drop('Class', axis=1)
y = df['Class']

# Instantiate oversampler and undersampler
oversampler = RandomOverSampler()
undersampler = RandomUnderSampler()

# Resample using both oversampling and undersampling
X_over, y_over = oversampler.fit_resample(X, y)
X_resampled, y_resampled = undersampler.fit_resample(X_over, y_over)

# Print the number of samples in each class
print("Number of samples in each class after resampling:")
print(y_resampled.value_counts())
# Out:
# Number of samples in each class after resampling:
# 0    763
# 1    763
# Name: Class, dtype: int64

# %%
X_resampled
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1522 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 1523  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1524 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1525 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
#
#             V8        V9       V10  ...       V20       V21       V22  \
# 0     0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838
# 1     0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679
# 2     0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274
# 3    -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278
# 4     0.260314 -0.568671 -0.371407  ...  0.084968 -0.208254 -0.559825
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521 -0.067794 -0.270953 -0.838587  ...  2.102339  0.661696  0.435477
# 1522 -0.156590 -0.142117 -0.574775  ... -0.118283  0.066353  0.281378
# 1523 -0.202836  0.035154 -0.282617  ... -0.079756 -0.287592 -0.832682
# 1524  1.391657 -2.770089 -2.772272  ...  0.126911  0.517232 -0.035049
# 1525  0.140631  0.023464 -0.066407  ...  0.002974 -0.179545 -0.192036
#
#            V23       V24       V25       V26       V27       V28    Amount
# 0    -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729
# 1     0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  0.065115
# 2    -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237
# 3    -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153  0.012036
# 4    -0.026398 -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  1.375966 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968
# 1522 -0.257966  0.385384  0.391117 -0.453853 -0.104448 -0.125765  0.000172
# 1523  0.128083  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463
# 1524 -0.465211  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000
# 1525 -0.261879 -0.237477 -0.335040  0.240323 -0.345129 -0.383563  0.000172
#
# [1526 rows x 29 columns]

# %%
new_df = pd.concat([X_resampled, y_resampled], axis=1)
new_df
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1522 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 1523  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1524 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1525 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 1     0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 2     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 3    -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
# 4     0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1522 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966
# 1523 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 1524  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 1525  0.140631  0.023464 -0.066407  ... -0.179545 -0.192036 -0.261879
#
#            V24       V25       V26       V27       V28    Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 1    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  0.065115      0
# 2    -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 3     0.141267 -0.206010  0.502292  0.219422  0.215153  0.012036      0
# 4    -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1521 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1522  0.385384  0.391117 -0.453853 -0.104448 -0.125765  0.000172      1
# 1523  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 1524  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
# 1525 -0.237477 -0.335040  0.240323 -0.345129 -0.383563  0.000172      1
#
# [1526 rows x 30 columns]

# %%
class_freq = new_df['Class'].value_counts()
print(f"Number of classes: {len(class_freq)}")
print("Class frequencies:")
print(class_freq)
# Out:
# Number of classes: 2
# Class frequencies:
# 0    763
# 1    763
# Name: Class, dtype: int64

# %%
n = int((2.326*2.326 * 0.5*0.5)/(0.05**2))
sampled_df = new_df.sample(n=n, random_state=42)
sampled_df
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 1439 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 76    0.921544 -0.067084  0.077461  0.953638  0.067412  0.016152  0.320452
# 1010 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 660   0.074738 -3.032009 -0.429919 -0.442721 -1.784710 -0.066668  0.098736
# 1132  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480  0.296319
# ...        ...       ...       ...       ...       ...       ...       ...
# 621  -0.347240  1.140218  1.289066  0.061070  0.032514 -0.960933  0.756415
# 590  -1.146103  1.350274  0.907209 -0.040682 -0.242920 -1.099859  0.579042
# 1497 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 888  -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
# 809   1.257719  0.364739  0.306923  0.690638 -0.357792 -1.067481  0.094272
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 1439  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 76    0.038534 -0.391513  0.031560  ... -0.333930 -1.299920  0.084311
# 1010 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966
# 660  -0.222525 -0.241858  0.158664  ... -0.078927 -1.247242 -0.620402
# 1132  0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932  0.151012
# ...        ...       ...       ...  ...       ...       ...       ...
# 621  -0.091273 -0.439727 -0.525815  ... -0.257643 -0.667492 -0.005055
# 590   0.045619  0.460784  0.470425  ... -0.396947 -0.895759  0.099686
# 1497  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 888   0.140631  0.023464 -0.066407  ... -0.179545 -0.192036 -0.261879
# 809  -0.210300  0.014455 -0.286012  ... -0.286856 -0.820658  0.127663
#
#            V24       V25       V26       V27       V28    Amount  Class
# 1439  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
# 76   -0.370398  0.155102 -0.834490  0.000909  0.035547  0.023303      0
# 1010  0.385384  0.391117 -0.453853 -0.104448 -0.125765  0.000172      1
# 660  -0.368545 -0.073359  1.296835 -0.192760  0.121440  0.122578      0
# 1132 -1.363967 -1.389079  0.075412  0.231750  0.230171  0.000170      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 621   0.335569 -0.148201  0.071064  0.245460  0.099186  0.001635      0
# 590   0.275643 -0.045217  0.095849  0.563119  0.307945  0.003094      0
# 1497  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
# 888  -0.237477 -0.335040  0.240323 -0.345129 -0.383563  0.000172      1
# 809   0.343128  0.221120  0.094391 -0.022189  0.030944  0.000222      1
#
# [541 rows x 30 columns]

# %%
X = sampled_df.iloc[:, :-1].values
y = sampled_df.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[53  8]
#  [ 0 75]]
# 0.9411764705882353

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[47 14]
#  [19 56]]
# 0.7573529411764706

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 23)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[60  1]
#  [ 0 75]]
# 0.9926470588235294

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[47 14]
#  [ 0 75]]
# 0.8970588235294118

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[55  6]
#  [ 0 75]]
# 0.9558823529411765

# %%
interval = 2
systematic_df = new_df.iloc[::interval]
systematic_df
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6    -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8    -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# ...        ...       ...       ...       ...       ...       ...       ...
# 1516  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480  0.296319
# 1518 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1520 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
# 1522 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 1524 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 2     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 4     0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398
# 6    -3.807864  0.615375  1.249376  ...  1.943465 -1.015455  0.057504
# 8     0.069539 -0.736727 -0.366846  ... -0.246914 -0.633753 -0.120794
# ...        ...       ...       ...  ...       ...       ...       ...
# 1516  0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932  0.151012
# 1518 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1520  0.140631  0.023464 -0.066407  ... -0.179545 -0.192036 -0.261879
# 1522 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966
# 1524  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
#
#            V24       V25       V26       V27       V28    Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 2    -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 4    -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631      0
# 6    -0.649709 -0.415267 -0.051634 -1.206921 -1.085339  0.007016      0
# 8    -0.385050 -0.069733  0.094199  0.246219  0.083076  0.000633      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1516 -1.363967 -1.389079  0.075412  0.231750  0.230171  0.000170      1
# 1518 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1520 -0.237477 -0.335040  0.240323 -0.345129 -0.383563  0.000172      1
# 1522  0.385384  0.391117 -0.453853 -0.104448 -0.125765  0.000172      1
# 1524  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
#
# [763 rows x 30 columns]

# %%
X = systematic_df.iloc[:, :-1].values
y = systematic_df.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[92  7]
#  [ 0 92]]
# 0.9633507853403142

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[95  4]
#  [55 37]]
# 0.6910994764397905

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 23)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[99  0]
#  [ 0 92]]
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[82 17]
#  [ 0 92]]
# 0.9109947643979057

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[98  1]
#  [ 0 92]]
# 0.9947643979057592

# %%
from sklearn.model_selection import train_test_split

n = int((2.326*2.326 * 0.5*0.5)/((0.05)**2))

strata = new_df.groupby('Class')

# sample 2 rows from each stratum
stratified_df = strata.apply(lambda x: x.sample(n))

stratified_df
# Out:
#                   V1        V2        V3        V4        V5        V6  \
# Class
# 0     424  -1.236351 -0.687029  2.093407  0.601217  0.782303 -1.167113
#       735  -0.332049  0.319511  1.234834 -1.843052 -0.349018 -0.947158
#       52    1.095525 -0.116085  1.397912  1.497547 -1.049124  0.072839
#       162   1.245744  0.438878  0.316140  1.107634 -0.178446 -0.941091
#       112   1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...              ...       ...       ...       ...       ...       ...
# 1     1255  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256
#       989   1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
#       1278  1.257719  0.364739  0.306923  0.690638 -0.357792 -1.067481
#       1154 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
#       1332  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480
#
#                   V7        V8        V9       V10  ...       V21       V22  \
# Class                                               ...
# 0     424  -0.675395  0.232563  0.500531 -0.565374  ...  0.378832  0.841499
#       735   0.238729 -0.068452 -1.051424  0.217333  ...  0.184122  0.506400
#       52   -0.723802  0.287532  0.996327 -0.149145  ... -0.033234  0.093262
#       162   0.286291 -0.290079 -0.169188 -0.014420  ...  0.038621  0.208207
#       112  -0.036715  0.350995  0.118950 -0.243289  ...  0.102520  0.605089
# ...              ...       ...       ...       ...  ...       ...       ...
# 1     1255  0.086781 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682
#       989  -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
#       1278  0.094272 -0.210300  0.014455 -0.286012  ... -0.286856 -0.820658
#       1154 -2.537387  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049
#       1332  0.296319  0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932
#
#                  V23       V24       V25       V26       V27       V28  \
# Class
# 0     424   0.150103  0.391760 -0.542331 -0.531517  0.186280  0.230012
#       735  -0.179405  0.014047 -0.163897 -0.388108  0.362961  0.200999
#       52    0.089498  0.361261  0.250963 -0.378280  0.081024  0.034227
#       162  -0.111479  0.419907  0.722345 -0.331446  0.020337  0.022443
#       112   0.023092 -0.626463  0.479120 -0.166937  0.081247  0.001192
# ...              ...       ...       ...       ...       ...       ...
# 1     1255  0.128083  0.339427  0.215944  0.094704 -0.023354  0.030892
#       989   0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
#       1278  0.127663  0.343128  0.221120  0.094391 -0.022189  0.030944
#       1154 -0.465211  0.320198  0.044519  0.177840  0.261145 -0.143276
#       1332  0.151012 -1.363967 -1.389079  0.075412  0.231750  0.230171
#
#               Amount  Class
# Class
# 0     424   0.001341      0
#       735   0.000679      0
#       52    0.000359      0
#       162   0.000721      0
#       112   0.000203      0
# ...              ...    ...
# 1     1255  0.000463      1
#       989   0.000463      1
#       1278  0.000222      1
#       1154  0.000000      1
#       1332  0.000170      1
#
# [1082 rows x 30 columns]

# %%
X = stratified_df.iloc[:, :-1].values
y = stratified_df.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[117   8]
#  [  0 146]]
# 0.9704797047970479

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[115  10]
#  [ 78  68]]
# 0.6752767527675276

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 23)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[125   0]
#  [  0 146]]
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[100  25]
#  [  0 146]]
# 0.9077490774907749

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[121   4]
#  [  0 146]]
# 0.985239852398524

# %%
# cluster sampling
import numpy as np

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=42).fit(new_df)
cluster_assignments = kmeans.labels_

# Select the clusters you want to include in the sample
selected_clusters = [0, 2, 4, 5, 8]

cluster_series = pd.Series(cluster_assignments)

# Create the new DataFrame containing only the rows from the selected clusters
df_cluster_sample = new_df[cluster_series.isin(selected_clusters)]

# %%
X = df_cluster_sample.iloc[:, :-1].values
y = df_cluster_sample.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[ 91   5]
#  [  0 116]]
# 0.9764150943396226

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[78 18]
#  [17 99]]
# 0.8349056603773585

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 23)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[ 96   0]
#  [  0 116]]
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[ 73  23]
#  [  0 116]]
# 0.8915094339622641

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[ 93   3]
#  [  0 116]]
# 0.9858490566037735

# %%
convenience_sample = pd.concat([new_df.head(380), new_df.tail(380)])
convenience_sample
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1522 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 1523  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1524 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1525 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 1     0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 2     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 3    -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
# 4     0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1522 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966
# 1523 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 1524  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 1525  0.140631  0.023464 -0.066407  ... -0.179545 -0.192036 -0.261879
#
#            V24       V25       V26       V27       V28    Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 1    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  0.065115      0
# 2    -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 3     0.141267 -0.206010  0.502292  0.219422  0.215153  0.012036      0
# 4    -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1521 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1522  0.385384  0.391117 -0.453853 -0.104448 -0.125765  0.000172      1
# 1523  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 1524  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
# 1525 -0.237477 -0.335040  0.240323 -0.345129 -0.383563  0.000172      1
#
# [760 rows x 30 columns]

# %%
X = convenience_sample.iloc[:, :-1].values
y = convenience_sample.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[89  6]
#  [ 0 95]]
# 0.968421052631579

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[78 17]
#  [11 84]]
# 0.8526315789473684

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 23)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[95  0]
#  [ 0 95]]
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[81 14]
#  [ 0 95]]
# 0.9263157894736842

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[93  2]
#  [ 0 95]]
# 0.9894736842105263
